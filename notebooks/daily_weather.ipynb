# %%
import pandas as pd

# %%
df = pd.read_csv('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/montreal/2020-01-01/2022-06-26?unitGroup=metric&include=days&key=NDD4FLZ37NRPKGD82DRZWXGHU&contentType=csv')
df
# Out:
#                      name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0    Montréal, QC, Canada  2020-01-01      1.1     -0.8   0.2          -0.6
# 1    Montréal, QC, Canada  2020-01-02      2.6     -1.0   0.9           2.2
# 2    Montréal, QC, Canada  2020-01-03      5.8      2.8   4.8           5.0
# 3    Montréal, QC, Canada  2020-01-04      3.2     -1.9   0.5           3.2
# 4    Montréal, QC, Canada  2020-01-05     -1.8     -9.9  -5.3          -4.0
# ..                    ...         ...      ...      ...   ...           ...
# 903  Montréal, QC, Canada  2022-06-22     27.2     19.0  23.6          28.6
# 904  Montréal, QC, Canada  2022-06-23     21.8     12.6  16.8          21.8
# 905  Montréal, QC, Canada  2022-06-24     22.9     11.9  17.6          22.9
# 906  Montréal, QC, Canada  2022-06-25     21.4     12.8  16.1          21.4
# 907  Montréal, QC, Canada  2022-06-26     19.1     12.6  15.2          19.1
#
# ...

# %%
df.to_csv('../data/daily-weather.csv', index=False)

# %%
future = pd.read_csv('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/montreal/next7days?unitGroup=metric&include=days&key=NDD4FLZ37NRPKGD82DRZWXGHU&contentType=csv')
future
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /workspaces/hourly-report/notebooks/daily_weather.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bdrdevinhopkins-hourly-report-qgggrxx9fx4v9/workspaces/hourly-report/notebooks/daily_weather.ipynb#ch0000002vscode-remote?line=0'>1</a> future = pd.read_csv('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/montreal/next7days?unitGroup=metric&include=days&key=NDD4FLZ37NRPKGD82DRZWXGHU&contentType=csv')
#       <a href='vscode-notebook-cell://codespaces%2Bdrdevinhopkins-hourly-report-qgggrxx9fx4v9/workspaces/hourly-report/notebooks/daily_weather.ipynb#ch0000002vscode-remote?line=1'>2</a> future
#
# ...
